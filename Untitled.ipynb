# %%
import pandas as pd

# %%
csv = "player_traditional_stats_20-21.csv"

# %%
df = pd.read_csv(csv, parse_dates=True)
df.drop(columns=["season_id","player_name","team_id",])
# Out:
#            player_id     team_id team_abbreviation   age  gp   w   l  w_pct  \
# 0       Aaron Gordon  1610612743               DEN  25.0  50  29  21  0.580
# 1      Aaron Holiday  1610612754               IND  24.0  66  30  36  0.455
# 2      Aaron Nesmith  1610612738               BOS  21.0  46  22  24  0.478
# 3        Abdel Nader  1610612756               PHX  27.0  24  16   8  0.667
# 4        Adam Mokoka  1610612741               CHI  22.0  14   3  11  0.214
# ..               ...         ...               ...   ...  ..  ..  ..    ...
# 535     Yogi Ferrell  1610612746               LAC  28.0  10   4   6  0.400
# 536    Yuta Watanabe  1610612761               TOR  26.0  50  24  26  0.480
# 537      Zach LaVine  1610612741               CHI  26.0  58  26  32  0.448
# 538       Zeke Nnaji  1610612743               DEN  20.0  42  30  12  0.714
# 539  Zion Williamson  1610612740               NOP  20.0  61  29  32  0.475
#
# ...
